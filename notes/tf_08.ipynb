# %% [markdown]
# # 0. Prerequisite

# %%
# Maximum rate at which stream output can be sent on iopub before they are limited.
# NotebookApp.iopub_data_rate_limit Float
# Default: 1000000 (bytes/sec)

# %%
# https://research.google.com/colaboratory/local-runtimes.html

# jupyter notebook   --NotebookApp.allow_origin='https://colab.research.google.com'   --port=8888   --NotebookApp.port_retries=0 --NotebookApp.iopub_data_rate_limit=1.0e10

# %% [markdown]
# # Review

# %% [markdown]
# https://github.com/tensorflow/tensorboard
#
# TensorBoard is a suite of web applications for inspecting and understanding your TensorFlow runs and graphs.

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# !pwd

# %%
# Clear any logs from previous runs
# !del .\logs

# %%
import tensorflow as tf
import datetime

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
def create_model():
  return tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28), name='layers_flatten'),
    tf.keras.layers.Dense(512, activation='relu', name='layers_dense'),
    tf.keras.layers.Dropout(0.2, name='layers_dropout'),
    tf.keras.layers.Dense(10, activation='softmax', name='layers_dense_2')
  ])

model = create_model()

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# You're now ready to define, train and evaluate your model.
#
# To log the loss scalar as you train, you'll do the following:
#
# * Create the Keras TensorBoard callback
# * Specify a log directory
# * Pass the TensorBoard callback to Keras' Model.fit().

# %%
log_dir = "logs1/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
model.fit(x=x_train, 
          y=y_train, 
          epochs=5, 
          validation_data=(x_test, y_test), 
          callbacks=[tensorboard_callback])
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.fit(x=x_train,
#       2           y=y_train,
#       3           epochs=5,
#       4           validation_data=(x_test, y_test),
#       5           callbacks=[tensorboard_callback])
#
# File D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File D:\tensorflow\venv\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InternalError: Graph execution error:
#
# Detected at node 'sequential/layers_dense/MatMul' defined at (most recent call last):
#     File "C:\Python310\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Python310\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "D:\tensorflow\venv\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#       app.start()
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#       self.io_loop.start()
#     File "D:\tensorflow\venv\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Python310\lib\asyncio\base_events.py", line 603, in run_forever
#       self._run_once()
#     File "C:\Python310\lib\asyncio\base_events.py", line 1909, in _run_once
#       handle._run()
#     File "C:\Python310\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#       result = self._run_cell(
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#       result = runner(coro)
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\SW\AppData\Local\Temp\ipykernel_13720\123636535.py", line 1, in <module>
#       model.fit(x=x_train,
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\layers\core\dense.py", line 241, in call
#       outputs = tf.matmul(a=inputs, b=self.kernel)
# Node: 'sequential/layers_dense/MatMul'
# Attempting to perform BLAS operation using StreamExecutor without BLAS support
# 	 [[{{node sequential/layers_dense/MatMul}}]] [Op:__inference_train_function_626]

# %%
# %tensorboard --logdir logs/fit --port 6007
# Out:
#       <iframe id="tensorboard-frame-c4195dde945938cb" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c4195dde945938cb");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# **How TensorBoard gets data from TensorFlow**
#
# For this, you need **summary ops**. Summary ops are ops, just like tf.matmul and tf.nn.relu, which means they take in tensors, produce tensors, and are evaluated from within a TensorFlow graph.
#
# However, summary ops have a twist:
#
# * The tensors they produce contain serialized protobufs, which are written to disk and sent to TensorBoard.
#
# * To visualize the summary data in TensorBoard, you should evaluate the summary op, retrieve the result, and then write that result to disk using a **summary.FileWriter**.
#
# The supported summary ops include:
#
# * tf.summary.scalar
# * tf.summary.image
# * tf.summary.audio
# * tf.summary.text
# * tf.summary.histogram

# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
from datetime import datetime
from packaging import version

import tensorflow as tf
from tensorflow import keras
from keras import backend as K

import numpy as np

print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >= 2, \
    "This notebook requires TensorFlow 2.0 or above."
# Out:
# TensorFlow version:  2.11.1

# %%
# Clear any logs from previous runs
# !rm -rf ./logs/

# %%
data_size = 1000
# 80% of the data is for training.
train_pct = 0.8

train_size = int(data_size * train_pct)

# Create some input data between -1 and 1 and randomize it.
x = np.linspace(-1, 1, data_size)
np.random.shuffle(x)

# Generate the output data.
# y = 0.5x + 2 + noise
y = 0.5 * x + 2 + np.random.normal(0, 0.05, (data_size, ))

# Split into test and train pairs.
x_train, y_train = x[:train_size], y[:train_size]
x_test, y_test = x[train_size:], y[train_size:]

# %% [markdown]
# What if you want to log custom values, such as a dynamic learning rate? To do that, you need to use the TensorFlow Summary API.
#
# Retrain the regression model and log a custom learning rate. Here's how:
#
# 1. Create a file writer, using **tf.summary.create_file_writer()**.
# 2. Define a custom learning rate function. This will be passed to the Keras LearningRateScheduler callback.
# 3. Inside the learning rate function, use **tf.summary.scalar()** to log the custom learning rate.
# 4. Pass the LearningRateScheduler callback to Model.fit().

# %%
logdir = "logs/scalars/" + datetime.now().strftime("%Y%m%d-%H%M%S")
file_writer = tf.summary.create_file_writer(logdir + "/metrics")
file_writer.set_as_default()

# %%
def lr_schedule(epoch):
  """
  Returns a custom learning rate that decreases as epochs progress.
  """
  learning_rate = 0.2
  if epoch > 10:
    learning_rate = 0.02
  if epoch > 20:
    learning_rate = 0.01
  if epoch > 50:
    learning_rate = 0.005

  tf.summary.scalar('learning rate', data=learning_rate, step=epoch)
  return learning_rate

lr_callback = keras.callbacks.LearningRateScheduler(lr_schedule)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(16, input_dim=1),
    keras.layers.Dense(1),
])

model.compile(
    loss='mse', # keras.losses.mean_squared_error
    optimizer=keras.optimizers.SGD(),
)

training_history = model.fit(
    x_train, # input
    y_train, # output
    batch_size=train_size,
    verbose=1, # Suppress chatty output; use Tensorboard instead
    epochs=100,
    validation_data=(x_test, y_test),
    callbacks=[tensorboard_callback, lr_callback],
)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 199ms/step - loss: 4.7325 - val_loss: 0.2369 - lr: 0.2000
# Epoch 2/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2402 - val_loss: 0.0766 - lr: 0.2000
# Epoch 3/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0803 - val_loss: 0.0262 - lr: 0.2000
# Epoch 4/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0272 - val_loss: 0.0096 - lr: 0.2000
# Epoch 5/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0100 - val_loss: 0.0046 - lr: 0.2000
# Epoch 6/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0031 - lr: 0.2000
# Epoch 7/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0032 - val_loss: 0.0027 - lr: 0.2000
# Epoch 8/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0027 - val_loss: 0.0025 - lr: 0.2000
# Epoch 9/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0026 - val_loss: 0.0025 - lr: 0.2000
# Epoch 10/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.2000
# Epoch 11/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.2000
# Epoch 12/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0200
# Epoch 13/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0200
# Epoch 14/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0200
# Epoch 15/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0200
# Epoch 16/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0200
# Epoch 17/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0200
# Epoch 18/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0200
# Epoch 19/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0200
# Epoch 20/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0200
# Epoch 21/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0200
# Epoch 22/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 23/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 24/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 25/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 26/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 27/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 28/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 29/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 30/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 31/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 32/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 33/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 34/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 35/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 36/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 37/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 38/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 39/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 40/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 41/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 42/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 43/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 44/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 45/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 46/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 47/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 48/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 49/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 50/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 51/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0100
# Epoch 52/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 53/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 54/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 55/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 56/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 57/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 58/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 59/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 60/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 61/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 62/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 63/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 64/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 65/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 66/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 67/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 68/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 69/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 70/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 71/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 72/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 73/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 74/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 75/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 76/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 77/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 78/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 79/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 80/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 81/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 82/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 83/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 84/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 85/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 86/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 87/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 88/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 89/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 90/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 91/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 92/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 93/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 94/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 95/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 96/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 97/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 98/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 99/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050
# Epoch 100/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0050

# %%
# %tensorboard --logdir logs/scalars --port 6009

# %% [markdown]
# # Step32 - Weight Initialization & The Vanishing Gradient Problem
#
#
# <img src="https://global-uploads.webflow.com/5ef788f07804fb7d78a4127a/6245a9aca7defe61cea5ea7d_Engati-vanishing-point-problem.jpg" width=400><img src="https://miro.medium.com/max/1178/1*54WxyNRIoO6OX8Jwa-caeQ.webp" width=400>
#
#
#
# * gradient vanishing problem, 미분값 최대 0.25,
# * 이것을 $0.25^7 = 0.000061035 $

# %%
# %load_ext tensorboard
#%reload_ext tensorboard
# !rm -rf ./logs/
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
#1
(x_train, y_train), (x_test, y_test) = mnist.load_data()

#2:normalize images
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')
x_train /= 255.0 # [0, 1]
x_test  /= 255.0

#3: one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train) # (60000, 10)
y_test = tf.keras.utils.to_categorical(y_test)   # (10000, 10)

# %%
#4: build a model
init = tf.keras.initializers.Constant(0.1)
##init = tf.keras.initializers.RandomUniform(-0.5, 0.5) # 'random_uniform’

# %%
# kernel_initializer='glorot_uniform',

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(units=5, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=5, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=5, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=5, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=5, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=10,activation='softmax', kernel_initializer=init))
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_9 (Flatten)         (None, 784)               0
#
#  dense_60 (Dense)            (None, 5)                 3925
#
#  dense_61 (Dense)            (None, 5)                 30
#
#  dense_62 (Dense)            (None, 5)                 30
#
#  dense_63 (Dense)            (None, 5)                 30
#
#  dense_64 (Dense)            (None, 5)                 30
#
#  dense_65 (Dense)            (None, 10)                60
#
# =================================================================
# Total params: 4,105
# Trainable params: 4,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
log_dir = "./logs/3201/"
file_writer = tf.summary.create_file_writer(log_dir + "/gradient")
file_writer.set_as_default()

# %%
#6:  calculate averages and histograms of gradients in layers
class GradientCallback(tf.keras.callbacks.Callback):
  def __init__(self, freq=10):
  ##        super(GradientCallback, self).__init__()
      self.freq = freq

  def on_epoch_end(self, epoch, logs):
      if epoch%self.freq != 0:
          return

      with tf.GradientTape() as tape:
          y_pred = model(x_train)  # tensor, logits           
          loss   = tf.keras.losses.binary_crossentropy(y_train, y_pred)
      grads = tape.gradient(loss, model.trainable_weights)

      for n in range(1, len(model.layers)):
          i2 = (n-1)*2 # weights
          i1 = i2 + 1  # biases

          bias_avg   = tf.reduce_mean(tf.abs(grads[i1]))
          weight_avg = tf.reduce_mean(tf.abs(grads[i2]))
          
          tf.summary.scalar("layer_%d/avg/bias"%n, data=bias_avg, step=epoch)   
          tf.summary.scalar("layer_%d/avg/weight"%n, data=weight_avg, step=epoch)
          
          tf.summary.histogram("layer_%d/hist/bias"%n, data=grads[i1], step=epoch)
          tf.summary.histogram("layer_%d/hist/weight"%n, data=grads[i2], step=epoch)

          tf.print('epoch: {}, layer-{}, i1: {}, i2: {}'.format(epoch, n, i1, i2))
      
      feature_extractor = keras.Model(
          inputs=model.inputs,
          outputs=[layer.output for layer in model.layers],
      )
      features = feature_extractor(x_train)
      for i, f in enumerate(features):
        print('type_i: {}, type_f: {}'.format(type(i), type(f)))
        output_avg = tf.reduce_mean(tf.abs(f))
        tf.summary.scalar("layer_%d/avg/output"%i, data=output_avg, step=epoch)        
        tf.summary.histogram("layer_%d/hist/output"%i, data=f, step=epoch)
      
  def on_train_end(self, logs):
      tf.summary.flush()

callback1 = GradientCallback() # freq = 10
callback2 = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq= 10) #profile_batch=0

# %%
#7: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=101, batch_size=200, validation_split=0.2,
                 verbose=1, callbacks=[callback1, callback2])
# Out:
# Epoch 1/101
#   1/240 [..............................] - ETA: 2:35 - loss: 2.3026 - accuracy: 0.0800WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0012s vs `on_train_batch_end` time: 0.0013s). Check your callbacks.
# 229/240 [===========================>..] - ETA: 0s - loss: 2.3023 - accuracy: 0.1117epoch: 0, layer-1, i1: 1, i2: 0
# epoch: 0, layer-2, i1: 3, i2: 2
# epoch: 0, layer-3, i1: 5, i2: 4
# epoch: 0, layer-4, i1: 7, i2: 6
# epoch: 0, layer-5, i1: 9, i2: 8
# epoch: 0, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 3s 11ms/step - loss: 2.3022 - accuracy: 0.1116 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 2/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 3/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1128 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 4/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1134 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 5/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3032 - val_accuracy: 0.1060
# Epoch 6/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 7/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3017 - accuracy: 0.1140 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 8/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1135 - val_loss: 2.3030 - val_accuracy: 0.1060
# Epoch 9/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3015 - accuracy: 0.1138 - val_loss: 2.3028 - val_accuracy: 0.1060
# Epoch 10/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 11/101
# 234/240 [============================>.] - ETA: 0s - loss: 2.3016 - accuracy: 0.1137epoch: 10, layer-1, i1: 1, i2: 0
# epoch: 10, layer-2, i1: 3, i2: 2
# epoch: 10, layer-3, i1: 5, i2: 4
# epoch: 10, layer-4, i1: 7, i2: 6
# epoch: 10, layer-5, i1: 9, i2: 8
# epoch: 10, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 2s 10ms/step - loss: 2.3016 - accuracy: 0.1133 - val_loss: 2.3028 - val_accuracy: 0.1060
# Epoch 12/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3017 - accuracy: 0.1134 - val_loss: 2.3032 - val_accuracy: 0.1060
# Epoch 13/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3017 - accuracy: 0.1138 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 14/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3029 - val_accuracy: 0.1060
# Epoch 15/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3019 - val_accuracy: 0.1060
# Epoch 16/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 17/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1135 - val_loss: 2.3029 - val_accuracy: 0.1060
# Epoch 18/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1138 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 19/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 20/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3014 - accuracy: 0.1132 - val_loss: 2.3030 - val_accuracy: 0.1060
# Epoch 21/101
# 222/240 [==========================>...] - ETA: 0s - loss: 2.3016 - accuracy: 0.1132epoch: 20, layer-1, i1: 1, i2: 0
# epoch: 20, layer-2, i1: 3, i2: 2
# epoch: 20, layer-3, i1: 5, i2: 4
# epoch: 20, layer-4, i1: 7, i2: 6
# epoch: 20, layer-5, i1: 9, i2: 8
# epoch: 20, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 3s 11ms/step - loss: 2.3015 - accuracy: 0.1137 - val_loss: 2.3033 - val_accuracy: 0.1060
# Epoch 22/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1139 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 23/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1138 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 24/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3030 - val_accuracy: 0.1060
# Epoch 25/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1139 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 26/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1136 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 27/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1133 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 28/101
# 240/240 [==============================] - 1s 2ms/step - loss: 2.3017 - accuracy: 0.1136 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 29/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1139 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 30/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 31/101
# 215/240 [=========================>....] - ETA: 0s - loss: 2.3017 - accuracy: 0.1139epoch: 30, layer-1, i1: 1, i2: 0
# epoch: 30, layer-2, i1: 3, i2: 2
# epoch: 30, layer-3, i1: 5, i2: 4
# epoch: 30, layer-4, i1: 7, i2: 6
# epoch: 30, layer-5, i1: 9, i2: 8
# epoch: 30, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 3s 11ms/step - loss: 2.3017 - accuracy: 0.1140 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 32/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3032 - val_accuracy: 0.1060
# Epoch 33/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3028 - val_accuracy: 0.1060
# Epoch 34/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3015 - accuracy: 0.1139 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 35/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3016 - accuracy: 0.1135 - val_loss: 2.3029 - val_accuracy: 0.1060
# Epoch 36/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3015 - accuracy: 0.1131 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 37/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 38/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1138 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 39/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3030 - val_accuracy: 0.1060
# Epoch 40/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 41/101
# 213/240 [=========================>....] - ETA: 0s - loss: 2.3015 - accuracy: 0.1139epoch: 40, layer-1, i1: 1, i2: 0
# epoch: 40, layer-2, i1: 3, i2: 2
# epoch: 40, layer-3, i1: 5, i2: 4
# epoch: 40, layer-4, i1: 7, i2: 6
# epoch: 40, layer-5, i1: 9, i2: 8
# epoch: 40, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 2s 10ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 42/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3016 - accuracy: 0.1135 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 43/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 44/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1134 - val_loss: 2.3020 - val_accuracy: 0.1081
# Epoch 45/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1133 - val_loss: 2.3019 - val_accuracy: 0.1060
# Epoch 46/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1134 - val_loss: 2.3030 - val_accuracy: 0.1060
# Epoch 47/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 48/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3015 - accuracy: 0.1137 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 49/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1133 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 50/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1138 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 51/101
# 208/240 [=========================>....] - ETA: 0s - loss: 2.3015 - accuracy: 0.1137epoch: 50, layer-1, i1: 1, i2: 0
# epoch: 50, layer-2, i1: 3, i2: 2
# epoch: 50, layer-3, i1: 5, i2: 4
# epoch: 50, layer-4, i1: 7, i2: 6
# epoch: 50, layer-5, i1: 9, i2: 8
# epoch: 50, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 3s 11ms/step - loss: 2.3016 - accuracy: 0.1139 - val_loss: 2.3033 - val_accuracy: 0.1060
# Epoch 52/101
# 240/240 [==============================] - 1s 2ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 53/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 54/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3014 - accuracy: 0.1137 - val_loss: 2.3029 - val_accuracy: 0.1035
# Epoch 55/101
# 240/240 [==============================] - 1s 3ms/step - loss: 2.3016 - accuracy: 0.1128 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 56/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 57/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3015 - accuracy: 0.1137 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 58/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 59/101
# 240/240 [==============================] - 1s 2ms/step - loss: 2.3015 - accuracy: 0.1132 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 60/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1136 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 61/101
# 209/240 [=========================>....] - ETA: 0s - loss: 2.3014 - accuracy: 0.1151epoch: 60, layer-1, i1: 1, i2: 0
# epoch: 60, layer-2, i1: 3, i2: 2
# epoch: 60, layer-3, i1: 5, i2: 4
# epoch: 60, layer-4, i1: 7, i2: 6
# epoch: 60, layer-5, i1: 9, i2: 8
# epoch: 60, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 2s 8ms/step - loss: 2.3016 - accuracy: 0.1136 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 62/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1135 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 63/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1132 - val_loss: 2.3035 - val_accuracy: 0.1060
# Epoch 64/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3028 - val_accuracy: 0.1060
# Epoch 65/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 66/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 67/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1131 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 68/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1138 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 69/101
# 240/240 [==============================] - 1s 2ms/step - loss: 2.3014 - accuracy: 0.1123 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 70/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3029 - val_accuracy: 0.1060
# Epoch 71/101
# 197/240 [=======================>......] - ETA: 0s - loss: 2.3016 - accuracy: 0.1128epoch: 70, layer-1, i1: 1, i2: 0
# epoch: 70, layer-2, i1: 3, i2: 2
# epoch: 70, layer-3, i1: 5, i2: 4
# epoch: 70, layer-4, i1: 7, i2: 6
# epoch: 70, layer-5, i1: 9, i2: 8
# epoch: 70, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 2s 10ms/step - loss: 2.3016 - accuracy: 0.1133 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 72/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3037 - val_accuracy: 0.1060
# Epoch 73/101
# 240/240 [==============================] - 1s 2ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 74/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3029 - val_accuracy: 0.1060
# Epoch 75/101
# 240/240 [==============================] - 1s 2ms/step - loss: 2.3015 - accuracy: 0.1139 - val_loss: 2.3019 - val_accuracy: 0.1060
# Epoch 76/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3016 - accuracy: 0.1131 - val_loss: 2.3029 - val_accuracy: 0.1060
# Epoch 77/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3028 - val_accuracy: 0.1060
# Epoch 78/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3015 - accuracy: 0.1137 - val_loss: 2.3030 - val_accuracy: 0.1060
# Epoch 79/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 80/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1138 - val_loss: 2.3032 - val_accuracy: 0.1060
# Epoch 81/101
# 201/240 [========================>.....] - ETA: 0s - loss: 2.3015 - accuracy: 0.1126epoch: 80, layer-1, i1: 1, i2: 0
# epoch: 80, layer-2, i1: 3, i2: 2
# epoch: 80, layer-3, i1: 5, i2: 4
# epoch: 80, layer-4, i1: 7, i2: 6
# epoch: 80, layer-5, i1: 9, i2: 8
# epoch: 80, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 2s 9ms/step - loss: 2.3016 - accuracy: 0.1130 - val_loss: 2.3031 - val_accuracy: 0.1060
# Epoch 82/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1139 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 83/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1136 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 84/101
# 240/240 [==============================] - 0s 2ms/step - loss: 2.3016 - accuracy: 0.1131 - val_loss: 2.3031 - val_accuracy: 0.1060
# Epoch 85/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 86/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1138 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 87/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1129 - val_loss: 2.3036 - val_accuracy: 0.1060
# Epoch 88/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 89/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1135 - val_loss: 2.3028 - val_accuracy: 0.1060
# Epoch 90/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3014 - accuracy: 0.1137 - val_loss: 2.3037 - val_accuracy: 0.1060
# Epoch 91/101
# 209/240 [=========================>....] - ETA: 0s - loss: 2.3013 - accuracy: 0.1150epoch: 90, layer-1, i1: 1, i2: 0
# epoch: 90, layer-2, i1: 3, i2: 2
# epoch: 90, layer-3, i1: 5, i2: 4
# epoch: 90, layer-4, i1: 7, i2: 6
# epoch: 90, layer-5, i1: 9, i2: 8
# epoch: 90, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 2s 9ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 92/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 93/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1134 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 94/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1135 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 95/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1135 - val_loss: 2.3019 - val_accuracy: 0.1060
# Epoch 96/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1135 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 97/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 98/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3015 - accuracy: 0.1132 - val_loss: 2.3020 - val_accuracy: 0.1060
# Epoch 99/101
# 240/240 [==============================] - 0s 1ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 100/101
# 240/240 [==============================] - 1s 2ms/step - loss: 2.3015 - accuracy: 0.1135 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 101/101
# 201/240 [========================>.....] - ETA: 0s - loss: 2.3015 - accuracy: 0.1146epoch: 100, layer-1, i1: 1, i2: 0
# epoch: 100, layer-2, i1: 3, i2: 2
# epoch: 100, layer-3, i1: 5, i2: 4
# epoch: 100, layer-4, i1: 7, i2: 6
# epoch: 100, layer-5, i1: 9, i2: 8
# epoch: 100, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 3s 11ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3023 - val_accuracy: 0.1060

# %%
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=1)
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=1)
# Out:
# 1875/1875 [==============================] - 1s 758us/step - loss: 2.3013 - accuracy: 0.1124
# 313/313 [==============================] - 0s 719us/step - loss: 2.3012 - accuracy: 0.1135

# %%
print('train_loss: {:.2f}, train_acc: {:.2f}, test_loss: {:.2f}, test_acc: {:.2f}'\
      .format(train_loss, train_acc, test_loss, test_acc))
# Out:
# train_loss: 2.30, train_acc: 0.11, test_loss: 2.30, test_acc: 0.11

# %%
# %tensorboard --logdir ./logs/3201

# %%
from tensorboard import notebook
notebook.list() # View open TensorBoard instances
# Out:
# Known TensorBoard instances:
#   - port 6006: logdir ./logs/3201/ (started 0:28:49 ago; pid 9283)
#   - port 6008: logdir logs (started 0:20:43 ago; pid 12965)
#   - port 6010: logdir ./logs/3201 (started 0:01:56 ago; pid 26457)
#   - port 6009: logdir ./logs/3201 (started 0:10:49 ago; pid 20827)
#   - port 6007: logdir ./logs/3201/ (started 0:22:56 ago; pid 11936)

# %%
# Control TensorBoard display. If no port is provided, 
# the most recently launched TensorBoard is used
notebook.display(port=6007, height=1000)

# %% [markdown]
# https://www.deeplearning.ai/ai-notes/initialization/index.html
#
#
# | Initializers | Activation Functions|
# |--------------|---------------------|
# | tf.keras.initializers.GlorotNormal | Sigmoid, Tanh |
# | tf.keras.initializers.HeNormal | ReLU, LeakyReLu |

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
import datetime
#1
(x_train, y_train), (x_test, y_test) = mnist.load_data()

#2: normalize images
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')
x_train /= 255.0 # [0, 1]
x_test  /= 255.0

#3: one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train) # (60000, 10)
y_test = tf.keras.utils.to_categorical(y_test)   # (10000, 10)

#4: build a model
##init = tf.keras.initializers.glorot_uniform()    # 'glorot_uniform'
init = tf.keras.initializers.glorot_normal()       # 'glorot_normal'

n = 100 # 5
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(units=n, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=n, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=n, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=n, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=n, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=n, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=10,activation='softmax', kernel_initializer=init))
model.summary()

opt = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

#5: creates a summary file writer for the given log directory
#import os
#path = "c:\\tmp\\logs\\"
#if not os.path.isdir(path):
#    os.mkdir(path)
##logdir = path + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
logdir = './logs1/' + "3202"
file_writer = tf.summary.create_file_writer(logdir + "/gradient")
file_writer.set_as_default()

#6:  calculate averages and histograms of gradients in layers
class GradientCallback(tf.keras.callbacks.Callback):
    
    def __init__(self, freq=10):
##        super(GradientCallback, self).__init__()
        self.freq = freq

    def on_epoch_end(self, epoch, logs):
        if epoch%self.freq != 0:
            return
        with tf.GradientTape() as tape:
            y_pred = model(x_train)  # tensor, logits
            loss   = tf.keras.losses.binary_crossentropy(y_train, y_pred)
        grads = tape.gradient(loss, model.trainable_weights)
        for n in range(1, len(model.layers)):
            i2 = (n-1)*2 # weights
            i1 = i2 + 1  # biases

            bias_avg   = tf.reduce_mean(tf.abs(grads[i1]))
            weight_avg = tf.reduce_mean(tf.abs(grads[i2]))
            
            tf.summary.scalar("layer_%d/avg/bias"%n, data=bias_avg, step=epoch)   
            tf.summary.scalar("layer_%d/avg/weight"%n, data=weight_avg, step=epoch)
##            
            tf.summary.histogram("layer_%d/hist/bias"%n, data=grads[i1], step=epoch)
            tf.summary.histogram("layer_%d/hist/weight"%n, data=grads[i2], step=epoch)
            
    def on_train_end(self, logs):
        tf.summary.flush()

callback1 = GradientCallback() # freq = 10
callback2 = tf.keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq= 10) #profile_batch=0       
                                  
#7: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=101, batch_size=200, validation_split=0.2,
                 verbose=2, callbacks=[callback1, callback2])

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2)
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 784)               0
#
#  dense_21 (Dense)            (None, 100)               78500
#
#  dense_22 (Dense)            (None, 100)               10100
#
#  dense_23 (Dense)            (None, 100)               10100
#
#  dense_24 (Dense)            (None, 100)               10100
#
#  dense_25 (Dense)            (None, 100)               10100
#
#  dense_26 (Dense)            (None, 100)               10100
#
#  dense_27 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 130,010
# Trainable params: 130,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/101
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[11], line 82
#      79 callback2 = tf.keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq= 10) #profile_batch=0
#      81 #7: train and evaluate the model
# ---> 82 ret = model.fit(x_train, y_train, epochs=101, batch_size=200, validation_split=0.2,
#      83                  verbose=2, callbacks=[callback1, callback2])
#      85 train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2)
#      86 test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
#
# File D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File D:\tensorflow\venv\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InternalError: Graph execution error:
#
# Detected at node 'sequential_4/dense_21/MatMul' defined at (most recent call last):
#     File "C:\Python310\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Python310\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "D:\tensorflow\venv\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#       app.start()
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#       self.io_loop.start()
#     File "D:\tensorflow\venv\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Python310\lib\asyncio\base_events.py", line 603, in run_forever
#       self._run_once()
#     File "C:\Python310\lib\asyncio\base_events.py", line 1909, in _run_once
#       handle._run()
#     File "C:\Python310\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#       result = self._run_cell(
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#       result = runner(coro)
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\SW\AppData\Local\Temp\ipykernel_13720\2160480136.py", line 82, in <module>
#       ret = model.fit(x_train, y_train, epochs=101, batch_size=200, validation_split=0.2,
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\layers\core\dense.py", line 241, in call
#       outputs = tf.matmul(a=inputs, b=self.kernel)
# Node: 'sequential_4/dense_21/MatMul'
# Attempting to perform BLAS operation using StreamExecutor without BLAS support
# 	 [[{{node sequential_4/dense_21/MatMul}}]] [Op:__inference_train_function_3688]

# %%
# %tensorboard --logdir ./logs/3202 --port 6010

# %% [markdown]
# <img src="https://production-media.paperswithcode.com/methods/Screen_Shot_2020-05-27_at_1.18.53_PM_wFylRBX.png" width="400"/>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
import datetime
#1
(x_train, y_train), (x_test, y_test) = mnist.load_data()

#2: normalize images
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')
x_train /= 255.0 # [0, 1]
x_test  /= 255.0

#3: one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train) # (60000, 10)
y_test = tf.keras.utils.to_categorical(y_test)   # (10000, 10)

#4: build a model
#4-1
##init = tf.keras.initializers.he_normal() # 'he_normal'
##act =  tf.keras.activations.relu         # 'relu'

#4-2
##init = tf.keras.initializers.he_normal()   # 'he_normal'
##act = tf.keras.layers.LeakyReLU(alpha=0.3)

#4-3
init =  tf.keras.initializers.he_uniform() # 'he_uniform'
act = tf.keras.layers.LeakyReLU(alpha=0.3)

n = 100
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=10,activation='softmax', kernel_initializer=init))
model.summary()
opt = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

#5: creates a summary file writer for the given log directory
#import os
#path = "c:\\tmp\\logs\\"
#if not os.path.isdir(path):
#    os.mkdir(path)
##logdir = path + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
logdir = './logs1/' + "3203"

file_writer = tf.summary.create_file_writer(logdir + "/gradient")
file_writer.set_as_default()

#6:  calculate averages and histograms of gradients in layers
class GradientCallback(tf.keras.callbacks.Callback):
    
    def __init__(self, freq=10):
##        super(GradientCallback, self).__init__()
        self.freq = freq

    def on_epoch_end(self, epoch, logs):
        if epoch%self.freq != 0:
            return
        with tf.GradientTape() as tape:
            y_pred = model(x_train)  # tensor, logits
            loss   = tf.keras.losses.binary_crossentropy(y_train, y_pred)
        grads = tape.gradient(loss, model.trainable_weights)
        for n in range(1, len(model.layers)):
            i2 = (n-1)*2 # weights
            i1 = i2 + 1  # biases

            bias_avg   = tf.reduce_mean(tf.abs(grads[i1]))
            weight_avg = tf.reduce_mean(tf.abs(grads[i2]))
            
            tf.summary.scalar("layer_%d/avg/bias"%n, data=bias_avg, step=epoch)   
            tf.summary.scalar("layer_%d/avg/weight"%n, data=weight_avg, step=epoch)
##            
            tf.summary.histogram("layer_%d/hist/bias"%n, data=grads[i1], step=epoch)
            tf.summary.histogram("layer_%d/hist/weight"%n, data=grads[i2], step=epoch)
            
    def on_train_end(self, logs):
        tf.summary.flush()

callback1 = GradientCallback() # freq = 10
callback2 = tf.keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq= 10) #profile_batch=0      
                                  
#7: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=101, batch_size=200, validation_split=0.2,
                 verbose=2, callbacks=[callback1, callback2])

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2)
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_14 (Dense)            (None, 100)               78500
#
#  dense_15 (Dense)            (None, 100)               10100
#
#  dense_16 (Dense)            (None, 100)               10100
#
#  dense_17 (Dense)            (None, 100)               10100
#
#  dense_18 (Dense)            (None, 100)               10100
#
#  dense_19 (Dense)            (None, 100)               10100
#
#  dense_20 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 130,010
# Trainable params: 130,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/101
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[10], line 91
#      88 callback2 = tf.keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq= 10) #profile_batch=0
#      90 #7: train and evaluate the model
# ---> 91 ret = model.fit(x_train, y_train, epochs=101, batch_size=200, validation_split=0.2,
#      92                  verbose=2, callbacks=[callback1, callback2])
#      94 train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2)
#      95 test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
#
# File D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File D:\tensorflow\venv\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InternalError: Graph execution error:
#
# Detected at node 'sequential_3/dense_14/MatMul' defined at (most recent call last):
#     File "C:\Python310\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Python310\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "D:\tensorflow\venv\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#       app.start()
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#       self.io_loop.start()
#     File "D:\tensorflow\venv\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Python310\lib\asyncio\base_events.py", line 603, in run_forever
#       self._run_once()
#     File "C:\Python310\lib\asyncio\base_events.py", line 1909, in _run_once
#       handle._run()
#     File "C:\Python310\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "D:\tensorflow\venv\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#       result = self._run_cell(
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#       result = runner(coro)
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "D:\tensorflow\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\SW\AppData\Local\Temp\ipykernel_13720\153327077.py", line 91, in <module>
#       ret = model.fit(x_train, y_train, epochs=101, batch_size=200, validation_split=0.2,
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\tensorflow\venv\lib\site-packages\keras\layers\core\dense.py", line 241, in call
#       outputs = tf.matmul(a=inputs, b=self.kernel)
# Node: 'sequential_3/dense_14/MatMul'
# Attempting to perform BLAS operation using StreamExecutor without BLAS support
# 	 [[{{node sequential_3/dense_14/MatMul}}]] [Op:__inference_train_function_2377]

# %%
# %tensorboard --logdir ./logs/3203 --port 6011

# %% [markdown]
# # Step33 - Batch Normalization

# %% [markdown]
# * 데이터를 정규화하면 정확도가 높아짐
# * 레이어의 출력을 평균 0, 분산 1로 정규화함
# * 가중치 초기화에 영향을 덜 받음
# * 학습 속도를 빠르게 함
# * Overfitting 방지
#
# <img src="https://gaussian37.github.io/assets/img/dl/concept/batchnorm/2.png" width="400"/>
#
#
# <img src="https://gaussian37.github.io/assets/img/dl/concept/batchnorm/4.png" width="400"/>
#
# <img src="https://d3i71xaburhd42.cloudfront.net/94be567c32ae76bdaadabd4975807a94181e39b3/2-Figure1-1.png" width="400"/>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
import datetime
#1
(x_train, y_train), (x_test, y_test) = mnist.load_data()

#2:normalize images
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')
x_train /= 255.0 # [0, 1]
x_test  /= 255.0

#3: one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train) # (60000, 10)
y_test = tf.keras.utils.to_categorical(y_test)   # (10000, 10)

#4: build a model
##init = tf.keras.initializers.RandomNormal(mean = 0.0, stddev = 1.0 )
##init = tf.keras.initializers.RandomUniform(-0.5, 0.5)
init = tf.keras.initializers.RandomUniform(0.0, 1.0) 

n = 100
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(units=n, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(units=n, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(units=n, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(units=n, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(units=n, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(units=n, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(units=10, activation='softmax', kernel_initializer=init))
model.summary()

opt = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

#5: creates a summary file writer for the given log directory
#import os
#path = "c:\\tmp\\logs\\"
#if not os.path.isdir(path):
#    os.mkdir(path)
##logdir = path + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
logdir = './logs/' + "3301"

file_writer = tf.summary.create_file_writer(logdir + "/gradient")
file_writer.set_as_default()

#6:  calculate averages and histograms of gradients in layers
class GradientCallback(tf.keras.callbacks.Callback): 
  def __init__(self, freq=10):
##        super(GradientCallback, self).__init__()
      self.freq = freq

  def on_epoch_end(self, epoch, logs):
    if epoch%self.freq != 0:
        return

    with tf.GradientTape() as tape:
        y_pred = model(x_train)  # tensor, logits           
        loss   = tf.keras.losses.binary_crossentropy(y_train, y_pred)
    grads = tape.gradient(loss, model.trainable_weights)

    for n in range(1, len(model.layers)):
        i2 = (n-1)*2 # weights
        i1 = i2 + 1  # biases

        bias_avg   = tf.reduce_mean(tf.abs(grads[i1]))
        weight_avg = tf.reduce_mean(tf.abs(grads[i2]))
        
        tf.summary.scalar("layer_%d/avg/bias"%n, data=bias_avg, step=epoch)   
        tf.summary.scalar("layer_%d/avg/weight"%n, data=weight_avg, step=epoch)
        
        tf.summary.histogram("layer_%d/hist/bias"%n, data=grads[i1], step=epoch)
        tf.summary.histogram("layer_%d/hist/weight"%n, data=grads[i2], step=epoch)

        tf.print('epoch: {}, layer-{}, i1: {}, i2: {}'.format(epoch, n, i1, i2))
    
    feature_extractor = keras.Model(
        inputs=model.inputs,
        outputs=[layer.output for layer in model.layers],
    )
    features = feature_extractor(x_train)
    for i, f in enumerate(features):
      print('type_i: {}, type_f: {}'.format(type(i), type(f)))
      output_avg = tf.reduce_mean(tf.abs(f))
      tf.summary.scalar("layer_%d/avg/output"%i, data=output_avg, step=epoch)        
      tf.summary.histogram("layer_%d/hist/output"%i, data=f, step=epoch)
      
  def on_train_end(self, logs):
      tf.summary.flush()

callback1 = GradientCallback() # freq = 10
callback2 = tf.keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq= 10, profile_batch=0) 

#7: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=101, batch_size=200, validation_split=0.2,
                 verbose=2, callbacks=[callback1, callback2])

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2)
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_15 (Flatten)        (None, 784)               0
#
#  dense_101 (Dense)           (None, 100)               78500
#
#  batch_normalization_6 (Batc  (None, 100)              400
#  hNormalization)
#
#  dense_102 (Dense)           (None, 100)               10100
#
#  batch_normalization_7 (Batc  (None, 100)              400
#  hNormalization)
#
#  dense_103 (Dense)           (None, 100)               10100
#
#  batch_normalization_8 (Batc  (None, 100)              400
#  hNormalization)
#
#  dense_104 (Dense)           (None, 100)               10100
#
#  batch_normalization_9 (Batc  (None, 100)              400
#  hNormalization)
#
#  dense_105 (Dense)           (None, 100)               10100
#
#  batch_normalization_10 (Bat  (None, 100)              400
#  chNormalization)
#
#  dense_106 (Dense)           (None, 100)               10100
#
#  batch_normalization_11 (Bat  (None, 100)              400
#  chNormalization)
#
#  dense_107 (Dense)           (None, 10)                1010
#
# =================================================================
# Total params: 132,410
# Trainable params: 131,210
# Non-trainable params: 1,200
# _________________________________________________________________
# Epoch 1/101
# /home/edward/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# epoch: 0, layer-1, i1: 1, i2: 0
# epoch: 0, layer-2, i1: 3, i2: 2
# epoch: 0, layer-3, i1: 5, i2: 4
# epoch: 0, layer-4, i1: 7, i2: 6
# epoch: 0, layer-5, i1: 9, i2: 8
# epoch: 0, layer-6, i1: 11, i2: 10
# epoch: 0, layer-7, i1: 13, i2: 12
# epoch: 0, layer-8, i1: 15, i2: 14
# epoch: 0, layer-9, i1: 17, i2: 16
# epoch: 0, layer-10, i1: 19, i2: 18
# epoch: 0, layer-11, i1: 21, i2: 20
# epoch: 0, layer-12, i1: 23, i2: 22
# epoch: 0, layer-13, i1: 25, i2: 24
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 - 7s - loss: 2.2820 - accuracy: 0.1186 - val_loss: 6.1544 - val_accuracy: 0.0998 - 7s/epoch - 28ms/step
# Epoch 2/101
# 240/240 - 1s - loss: 2.1402 - accuracy: 0.1787 - val_loss: 7.5872 - val_accuracy: 0.1046 - 1s/epoch - 5ms/step
# Epoch 3/101
# 240/240 - 1s - loss: 2.0118 - accuracy: 0.2059 - val_loss: 3.2369 - val_accuracy: 0.1060 - 579ms/epoch - 2ms/step
# Epoch 4/101
# 240/240 - 1s - loss: 1.9658 - accuracy: 0.2256 - val_loss: 165.9731 - val_accuracy: 0.1060 - 846ms/epoch - 4ms/step
# Epoch 5/101
# 240/240 - 1s - loss: 1.7849 - accuracy: 0.2973 - val_loss: 94.8763 - val_accuracy: 0.1060 - 608ms/epoch - 3ms/step
# Epoch 6/101
# 240/240 - 1s - loss: 1.6516 - accuracy: 0.3485 - val_loss: 5.5907 - val_accuracy: 0.1132 - 1s/epoch - 5ms/step
# Epoch 7/101
# 240/240 - 1s - loss: 1.5789 - accuracy: 0.3788 - val_loss: 4.5330 - val_accuracy: 0.1270 - 925ms/epoch - 4ms/step
# Epoch 8/101
# 240/240 - 1s - loss: 1.4233 - accuracy: 0.4425 - val_loss: 4.8150 - val_accuracy: 0.1167 - 1s/epoch - 5ms/step
# Epoch 9/101
# 240/240 - 1s - loss: 1.3421 - accuracy: 0.4747 - val_loss: 16.1632 - val_accuracy: 0.0393 - 1s/epoch - 5ms/step
# Epoch 10/101
# 240/240 - 1s - loss: 1.3213 - accuracy: 0.4702 - val_loss: 49.8094 - val_accuracy: 0.0989 - 1s/epoch - 4ms/step
# Epoch 11/101
# epoch: 10, layer-1, i1: 1, i2: 0
# epoch: 10, layer-2, i1: 3, i2: 2
# epoch: 10, layer-3, i1: 5, i2: 4
# epoch: 10, layer-4, i1: 7, i2: 6
# epoch: 10, layer-5, i1: 9, i2: 8
# epoch: 10, layer-6, i1: 11, i2: 10
# epoch: 10, layer-7, i1: 13, i2: 12
# epoch: 10, layer-8, i1: 15, i2: 14
# epoch: 10, layer-9, i1: 17, i2: 16
# epoch: 10, layer-10, i1: 19, i2: 18
# epoch: 10, layer-11, i1: 21, i2: 20
# epoch: 10, layer-12, i1: 23, i2: 22
# epoch: 10, layer-13, i1: 25, i2: 24
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 - 6s - loss: 1.2993 - accuracy: 0.4720 - val_loss: 12.6084 - val_accuracy: 0.0738 - 6s/epoch - 25ms/step
# Epoch 12/101
# 240/240 - 1s - loss: 1.2946 - accuracy: 0.4741 - val_loss: 5.2730 - val_accuracy: 0.0098 - 1s/epoch - 5ms/step
# Epoch 13/101
# 240/240 - 1s - loss: 1.2827 - accuracy: 0.4852 - val_loss: 5.9976 - val_accuracy: 0.1179 - 1s/epoch - 4ms/step
# Epoch 14/101
# 240/240 - 1s - loss: 1.2744 - accuracy: 0.4878 - val_loss: 3.5415 - val_accuracy: 0.0348 - 1s/epoch - 5ms/step
# Epoch 15/101
# 240/240 - 1s - loss: 1.2733 - accuracy: 0.4817 - val_loss: 2.2243 - val_accuracy: 0.2428 - 803ms/epoch - 3ms/step
# Epoch 16/101
# 240/240 - 1s - loss: 1.2695 - accuracy: 0.4842 - val_loss: 8.9939 - val_accuracy: 0.0113 - 772ms/epoch - 3ms/step
# Epoch 17/101
# 240/240 - 1s - loss: 1.2618 - accuracy: 0.4919 - val_loss: 4.6051 - val_accuracy: 0.0951 - 555ms/epoch - 2ms/step
# Epoch 18/101
# 240/240 - 1s - loss: 1.4262 - accuracy: 0.4271 - val_loss: 3.0845 - val_accuracy: 0.0975 - 1s/epoch - 4ms/step
# Epoch 19/101
# 240/240 - 1s - loss: 1.2752 - accuracy: 0.4936 - val_loss: 5.8890 - val_accuracy: 0.1212 - 832ms/epoch - 3ms/step
# Epoch 20/101
# 240/240 - 0s - loss: 1.2521 - accuracy: 0.4991 - val_loss: 6.3553 - val_accuracy: 0.1367 - 449ms/epoch - 2ms/step
# Epoch 21/101
# epoch: 20, layer-1, i1: 1, i2: 0
# epoch: 20, layer-2, i1: 3, i2: 2
# epoch: 20, layer-3, i1: 5, i2: 4
# epoch: 20, layer-4, i1: 7, i2: 6
# epoch: 20, layer-5, i1: 9, i2: 8
# epoch: 20, layer-6, i1: 11, i2: 10
# epoch: 20, layer-7, i1: 13, i2: 12
# epoch: 20, layer-8, i1: 15, i2: 14
# epoch: 20, layer-9, i1: 17, i2: 16
# epoch: 20, layer-10, i1: 19, i2: 18
# epoch: 20, layer-11, i1: 21, i2: 20
# epoch: 20, layer-12, i1: 23, i2: 22
# epoch: 20, layer-13, i1: 25, i2: 24
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 - 6s - loss: 1.2532 - accuracy: 0.4993 - val_loss: 6.2133 - val_accuracy: 0.1867 - 6s/epoch - 25ms/step
# Epoch 22/101
# 240/240 - 1s - loss: 1.2602 - accuracy: 0.4979 - val_loss: 2.0698 - val_accuracy: 0.2608 - 837ms/epoch - 3ms/step
# Epoch 23/101
# 240/240 - 1s - loss: 1.2556 - accuracy: 0.5005 - val_loss: 3.0630 - val_accuracy: 0.0914 - 1s/epoch - 5ms/step
# Epoch 24/101
# 240/240 - 1s - loss: 1.2471 - accuracy: 0.4999 - val_loss: 5.9550 - val_accuracy: 0.0217 - 1s/epoch - 4ms/step
# Epoch 25/101
# 240/240 - 1s - loss: 1.2528 - accuracy: 0.5002 - val_loss: 2.4239 - val_accuracy: 0.2280 - 798ms/epoch - 3ms/step
# Epoch 26/101
# 240/240 - 1s - loss: 1.2495 - accuracy: 0.5043 - val_loss: 7.2003 - val_accuracy: 0.0496 - 1s/epoch - 4ms/step
# Epoch 27/101
# 240/240 - 1s - loss: 1.2469 - accuracy: 0.5038 - val_loss: 8.6544 - val_accuracy: 0.0958 - 1s/epoch - 5ms/step
# Epoch 28/101
# 240/240 - 1s - loss: 1.2510 - accuracy: 0.5011 - val_loss: 2.7387 - val_accuracy: 0.1797 - 1s/epoch - 5ms/step
# Epoch 29/101
# 240/240 - 1s - loss: 1.2439 - accuracy: 0.5055 - val_loss: 2.5227 - val_accuracy: 0.1355 - 1s/epoch - 6ms/step
# Epoch 30/101
# 240/240 - 1s - loss: 1.2497 - accuracy: 0.5010 - val_loss: 10.5731 - val_accuracy: 0.0161 - 1s/epoch - 6ms/step
# Epoch 31/101
# epoch: 30, layer-1, i1: 1, i2: 0
# epoch: 30, layer-2, i1: 3, i2: 2
# epoch: 30, layer-3, i1: 5, i2: 4
# epoch: 30, layer-4, i1: 7, i2: 6
# epoch: 30, layer-5, i1: 9, i2: 8
# epoch: 30, layer-6, i1: 11, i2: 10
# epoch: 30, layer-7, i1: 13, i2: 12
# epoch: 30, layer-8, i1: 15, i2: 14
# epoch: 30, layer-9, i1: 17, i2: 16
# epoch: 30, layer-10, i1: 19, i2: 18
# epoch: 30, layer-11, i1: 21, i2: 20
# epoch: 30, layer-12, i1: 23, i2: 22
# epoch: 30, layer-13, i1: 25, i2: 24
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 - 6s - loss: 1.2415 - accuracy: 0.5061 - val_loss: 4.8844 - val_accuracy: 0.1166 - 6s/epoch - 24ms/step
# Epoch 32/101
# 240/240 - 1s - loss: 1.2437 - accuracy: 0.5056 - val_loss: 2.7619 - val_accuracy: 0.1470 - 762ms/epoch - 3ms/step
# Epoch 33/101
# 240/240 - 1s - loss: 1.2412 - accuracy: 0.5045 - val_loss: 2.5350 - val_accuracy: 0.3192 - 1s/epoch - 4ms/step
# Epoch 34/101
# 240/240 - 1s - loss: 1.2441 - accuracy: 0.5029 - val_loss: 2.4760 - val_accuracy: 0.1527 - 1s/epoch - 5ms/step
# Epoch 35/101
# 240/240 - 1s - loss: 1.2398 - accuracy: 0.5053 - val_loss: 2.1374 - val_accuracy: 0.3002 - 929ms/epoch - 4ms/step
# Epoch 36/101
# 240/240 - 1s - loss: 1.2402 - accuracy: 0.5051 - val_loss: 8.3928 - val_accuracy: 0.1407 - 813ms/epoch - 3ms/step
# Epoch 37/101
# 240/240 - 1s - loss: 1.2405 - accuracy: 0.5066 - val_loss: 2.4857 - val_accuracy: 0.2129 - 885ms/epoch - 4ms/step
# Epoch 38/101
# 240/240 - 1s - loss: 1.2430 - accuracy: 0.5053 - val_loss: 2.4023 - val_accuracy: 0.3099 - 834ms/epoch - 3ms/step
# Epoch 39/101
# 240/240 - 1s - loss: 1.2352 - accuracy: 0.5103 - val_loss: 2.9510 - val_accuracy: 0.1353 - 915ms/epoch - 4ms/step
# Epoch 40/101
# 240/240 - 1s - loss: 1.2428 - accuracy: 0.5018 - val_loss: 2.3528 - val_accuracy: 0.2690 - 1s/epoch - 5ms/step
# Epoch 41/101
# epoch: 40, layer-1, i1: 1, i2: 0
# epoch: 40, layer-2, i1: 3, i2: 2
# epoch: 40, layer-3, i1: 5, i2: 4
# epoch: 40, layer-4, i1: 7, i2: 6
# epoch: 40, layer-5, i1: 9, i2: 8
# epoch: 40, layer-6, i1: 11, i2: 10
# epoch: 40, layer-7, i1: 13, i2: 12
# epoch: 40, layer-8, i1: 15, i2: 14
# epoch: 40, layer-9, i1: 17, i2: 16
# epoch: 40, layer-10, i1: 19, i2: 18
# epoch: 40, layer-11, i1: 21, i2: 20
# epoch: 40, layer-12, i1: 23, i2: 22
# epoch: 40, layer-13, i1: 25, i2: 24
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 - 6s - loss: 1.2448 - accuracy: 0.5035 - val_loss: 4.7034 - val_accuracy: 0.1072 - 6s/epoch - 26ms/step
# Epoch 42/101
# 240/240 - 1s - loss: 1.2368 - accuracy: 0.5053 - val_loss: 3.1499 - val_accuracy: 0.3072 - 1s/epoch - 5ms/step
# Epoch 43/101
# 240/240 - 1s - loss: 1.2378 - accuracy: 0.5081 - val_loss: 4.2913 - val_accuracy: 0.1157 - 1s/epoch - 5ms/step
# Epoch 44/101
# 240/240 - 1s - loss: 1.2386 - accuracy: 0.5051 - val_loss: 3.1763 - val_accuracy: 0.1879 - 790ms/epoch - 3ms/step
# Epoch 45/101
# 240/240 - 1s - loss: 1.2344 - accuracy: 0.5068 - val_loss: 3.4145 - val_accuracy: 0.2086 - 516ms/epoch - 2ms/step
# Epoch 46/101
# 240/240 - 1s - loss: 1.2330 - accuracy: 0.5105 - val_loss: 4.7967 - val_accuracy: 0.2003 - 1s/epoch - 4ms/step
# Epoch 47/101
# 240/240 - 1s - loss: 1.2365 - accuracy: 0.5065 - val_loss: 2.5118 - val_accuracy: 0.2605 - 910ms/epoch - 4ms/step
# Epoch 48/101
# 240/240 - 1s - loss: 1.2354 - accuracy: 0.5084 - val_loss: 2.7092 - val_accuracy: 0.2473 - 1s/epoch - 5ms/step
# Epoch 49/101
# 240/240 - 1s - loss: 1.2344 - accuracy: 0.5086 - val_loss: 4.4626 - val_accuracy: 0.1602 - 578ms/epoch - 2ms/step
# Epoch 50/101
# 240/240 - 1s - loss: 1.2344 - accuracy: 0.5091 - val_loss: 4.0319 - val_accuracy: 0.1215 - 1s/epoch - 5ms/step
# Epoch 51/101
# epoch: 50, layer-1, i1: 1, i2: 0
# epoch: 50, layer-2, i1: 3, i2: 2
# epoch: 50, layer-3, i1: 5, i2: 4
# epoch: 50, layer-4, i1: 7, i2: 6
# epoch: 50, layer-5, i1: 9, i2: 8
# epoch: 50, layer-6, i1: 11, i2: 10
# epoch: 50, layer-7, i1: 13, i2: 12
# epoch: 50, layer-8, i1: 15, i2: 14
# epoch: 50, layer-9, i1: 17, i2: 16
# epoch: 50, layer-10, i1: 19, i2: 18
# epoch: 50, layer-11, i1: 21, i2: 20
# epoch: 50, layer-12, i1: 23, i2: 22
# epoch: 50, layer-13, i1: 25, i2: 24
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 - 6s - loss: 1.2343 - accuracy: 0.5063 - val_loss: 4.3059 - val_accuracy: 0.1001 - 6s/epoch - 26ms/step
# Epoch 52/101
# 240/240 - 1s - loss: 1.2311 - accuracy: 0.5096 - val_loss: 6.4477 - val_accuracy: 0.0373 - 1s/epoch - 6ms/step
# Epoch 53/101
# 240/240 - 1s - loss: 1.2322 - accuracy: 0.5093 - val_loss: 3.1334 - val_accuracy: 0.2308 - 919ms/epoch - 4ms/step
# Epoch 54/101
# 240/240 - 1s - loss: 1.2337 - accuracy: 0.5083 - val_loss: 2.4656 - val_accuracy: 0.2077 - 1s/epoch - 5ms/step
# Epoch 55/101
# 240/240 - 1s - loss: 1.2288 - accuracy: 0.5124 - val_loss: 5.3790 - val_accuracy: 0.1787 - 866ms/epoch - 4ms/step
# Epoch 56/101
# 240/240 - 1s - loss: 1.2298 - accuracy: 0.5104 - val_loss: 6.3216 - val_accuracy: 0.0403 - 1s/epoch - 4ms/step
# Epoch 57/101
# 240/240 - 1s - loss: 1.2380 - accuracy: 0.5046 - val_loss: 4.5321 - val_accuracy: 0.0862 - 634ms/epoch - 3ms/step
# Epoch 58/101
# 240/240 - 1s - loss: 1.2457 - accuracy: 0.5073 - val_loss: 2.3688 - val_accuracy: 0.2726 - 1s/epoch - 5ms/step
# Epoch 59/101
# 240/240 - 1s - loss: 1.2395 - accuracy: 0.5073 - val_loss: 7.4711 - val_accuracy: 0.1152 - 1s/epoch - 5ms/step
# Epoch 60/101
# 240/240 - 1s - loss: 1.2326 - accuracy: 0.5074 - val_loss: 5.2207 - val_accuracy: 0.3677 - 920ms/epoch - 4ms/step
# Epoch 61/101
# epoch: 60, layer-1, i1: 1, i2: 0
# epoch: 60, layer-2, i1: 3, i2: 2
# epoch: 60, layer-3, i1: 5, i2: 4
# epoch: 60, layer-4, i1: 7, i2: 6
# epoch: 60, layer-5, i1: 9, i2: 8
# epoch: 60, layer-6, i1: 11, i2: 10
# epoch: 60, layer-7, i1: 13, i2: 12
# epoch: 60, layer-8, i1: 15, i2: 14
# epoch: 60, layer-9, i1: 17, i2: 16
# epoch: 60, layer-10, i1: 19, i2: 18
# epoch: 60, layer-11, i1: 21, i2: 20
# epoch: 60, layer-12, i1: 23, i2: 22
# epoch: 60, layer-13, i1: 25, i2: 24
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 - 6s - loss: 1.2332 - accuracy: 0.5087 - val_loss: 2.4997 - val_accuracy: 0.2439 - 6s/epoch - 24ms/step
# Epoch 62/101
# 240/240 - 1s - loss: 1.2320 - accuracy: 0.5066 - val_loss: 6.9631 - val_accuracy: 0.0175 - 834ms/epoch - 3ms/step
# Epoch 63/101
# 240/240 - 1s - loss: 1.2306 - accuracy: 0.5108 - val_loss: 7.0184 - val_accuracy: 0.1458 - 1s/epoch - 4ms/step
# Epoch 64/101
# 240/240 - 1s - loss: 1.2380 - accuracy: 0.5078 - val_loss: 4.1852 - val_accuracy: 0.2222 - 1s/epoch - 4ms/step
# Epoch 65/101
# 240/240 - 1s - loss: 1.2365 - accuracy: 0.5065 - val_loss: 5.8583 - val_accuracy: 0.3277 - 1s/epoch - 5ms/step
# Epoch 66/101
# 240/240 - 1s - loss: 1.2326 - accuracy: 0.5065 - val_loss: 6.7157 - val_accuracy: 0.1185 - 1s/epoch - 5ms/step
# Epoch 67/101
# 240/240 - 1s - loss: 1.2336 - accuracy: 0.5098 - val_loss: 1.8263 - val_accuracy: 0.3556 - 626ms/epoch - 3ms/step
# Epoch 68/101
# 240/240 - 1s - loss: 1.2346 - accuracy: 0.5074 - val_loss: 4.5982 - val_accuracy: 0.2432 - 848ms/epoch - 4ms/step
# Epoch 69/101
# 240/240 - 1s - loss: 1.2317 - accuracy: 0.5103 - val_loss: 2.9183 - val_accuracy: 0.1769 - 1s/epoch - 5ms/step
# Epoch 70/101
# 240/240 - 1s - loss: 1.2354 - accuracy: 0.5080 - val_loss: 5.0487 - val_accuracy: 0.1733 - 1s/epoch - 5ms/step
# Epoch 71/101
# epoch: 70, layer-1, i1: 1, i2: 0
# epoch: 70, layer-2, i1: 3, i2: 2
# epoch: 70, layer-3, i1: 5, i2: 4
# epoch: 70, layer-4, i1: 7, i2: 6
# epoch: 70, layer-5, i1: 9, i2: 8
# epoch: 70, layer-6, i1: 11, i2: 10
# epoch: 70, layer-7, i1: 13, i2: 12
# epoch: 70, layer-8, i1: 15, i2: 14
# epoch: 70, layer-9, i1: 17, i2: 16
# epoch: 70, layer-10, i1: 19, i2: 18
# epoch: 70, layer-11, i1: 21, i2: 20
# epoch: 70, layer-12, i1: 23, i2: 22
# epoch: 70, layer-13, i1: 25, i2: 24
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 - 6s - loss: 1.2359 - accuracy: 0.5092 - val_loss: 4.9802 - val_accuracy: 0.1601 - 6s/epoch - 26ms/step
# Epoch 72/101
# 240/240 - 1s - loss: 1.2319 - accuracy: 0.5081 - val_loss: 2.6940 - val_accuracy: 0.2131 - 622ms/epoch - 3ms/step
# Epoch 73/101
# 240/240 - 1s - loss: 1.2347 - accuracy: 0.5076 - val_loss: 1.9664 - val_accuracy: 0.3564 - 979ms/epoch - 4ms/step
# Epoch 74/101
# 240/240 - 1s - loss: 1.2398 - accuracy: 0.5061 - val_loss: 9.3725 - val_accuracy: 0.2438 - 1s/epoch - 5ms/step
# Epoch 75/101
# 240/240 - 1s - loss: 1.2306 - accuracy: 0.5086 - val_loss: 8.9609 - val_accuracy: 0.1117 - 730ms/epoch - 3ms/step
# Epoch 76/101
# 240/240 - 1s - loss: 1.2312 - accuracy: 0.5055 - val_loss: 10.5546 - val_accuracy: 0.1367 - 874ms/epoch - 4ms/step
# Epoch 77/101
# 240/240 - 1s - loss: 1.2313 - accuracy: 0.5092 - val_loss: 2.6413 - val_accuracy: 0.1440 - 1s/epoch - 4ms/step
# Epoch 78/101
# 240/240 - 1s - loss: 1.2314 - accuracy: 0.5075 - val_loss: 7.3977 - val_accuracy: 0.1451 - 1s/epoch - 4ms/step
# Epoch 79/101
# 240/240 - 1s - loss: 1.2332 - accuracy: 0.5075 - val_loss: 8.3404 - val_accuracy: 0.1682 - 886ms/epoch - 4ms/step
# Epoch 80/101
# 240/240 - 1s - loss: 1.2311 - accuracy: 0.5101 - val_loss: 6.2484 - val_accuracy: 0.0235 - 893ms/epoch - 4ms/step
# Epoch 81/101
# epoch: 80, layer-1, i1: 1, i2: 0
# epoch: 80, layer-2, i1: 3, i2: 2
# epoch: 80, layer-3, i1: 5, i2: 4
# epoch: 80, layer-4, i1: 7, i2: 6
# epoch: 80, layer-5, i1: 9, i2: 8
# epoch: 80, layer-6, i1: 11, i2: 10
# epoch: 80, layer-7, i1: 13, i2: 12
# epoch: 80, layer-8, i1: 15, i2: 14
# epoch: 80, layer-9, i1: 17, i2: 16
# epoch: 80, layer-10, i1: 19, i2: 18
# epoch: 80, layer-11, i1: 21, i2: 20
# epoch: 80, layer-12, i1: 23, i2: 22
# epoch: 80, layer-13, i1: 25, i2: 24
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 - 6s - loss: 1.2272 - accuracy: 0.5101 - val_loss: 6.2188 - val_accuracy: 0.0607 - 6s/epoch - 25ms/step
# Epoch 82/101
# 240/240 - 1s - loss: 1.2327 - accuracy: 0.5068 - val_loss: 4.0722 - val_accuracy: 0.0547 - 1s/epoch - 5ms/step
# Epoch 83/101
# 240/240 - 1s - loss: 1.2288 - accuracy: 0.5101 - val_loss: 4.8460 - val_accuracy: 0.2122 - 877ms/epoch - 4ms/step
# Epoch 84/101
# 240/240 - 1s - loss: 1.2300 - accuracy: 0.5092 - val_loss: 2.5294 - val_accuracy: 0.2156 - 910ms/epoch - 4ms/step
# Epoch 85/101
# 240/240 - 1s - loss: 1.2300 - accuracy: 0.5124 - val_loss: 4.6100 - val_accuracy: 0.1862 - 1s/epoch - 5ms/step
# Epoch 86/101
# 240/240 - 1s - loss: 1.2340 - accuracy: 0.5101 - val_loss: 2.7293 - val_accuracy: 0.1785 - 1s/epoch - 4ms/step
# Epoch 87/101
# 240/240 - 1s - loss: 1.2297 - accuracy: 0.5097 - val_loss: 4.8619 - val_accuracy: 0.2313 - 1s/epoch - 5ms/step
# Epoch 88/101
# 240/240 - 1s - loss: 1.2283 - accuracy: 0.5090 - val_loss: 8.0906 - val_accuracy: 0.0190 - 764ms/epoch - 3ms/step
# Epoch 89/101
# 240/240 - 1s - loss: 1.2332 - accuracy: 0.5078 - val_loss: 6.6730 - val_accuracy: 0.1643 - 578ms/epoch - 2ms/step
# Epoch 90/101
# 240/240 - 1s - loss: 1.2281 - accuracy: 0.5099 - val_loss: 3.5287 - val_accuracy: 0.1063 - 890ms/epoch - 4ms/step
# Epoch 91/101
# epoch: 90, layer-1, i1: 1, i2: 0
# epoch: 90, layer-2, i1: 3, i2: 2
# epoch: 90, layer-3, i1: 5, i2: 4
# epoch: 90, layer-4, i1: 7, i2: 6
# epoch: 90, layer-5, i1: 9, i2: 8
# epoch: 90, layer-6, i1: 11, i2: 10
# epoch: 90, layer-7, i1: 13, i2: 12
# epoch: 90, layer-8, i1: 15, i2: 14
# epoch: 90, layer-9, i1: 17, i2: 16
# epoch: 90, layer-10, i1: 19, i2: 18
# epoch: 90, layer-11, i1: 21, i2: 20
# epoch: 90, layer-12, i1: 23, i2: 22
# epoch: 90, layer-13, i1: 25, i2: 24
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 - 6s - loss: 1.2292 - accuracy: 0.5108 - val_loss: 3.2412 - val_accuracy: 0.0998 - 6s/epoch - 25ms/step
# Epoch 92/101
# 240/240 - 1s - loss: 1.2304 - accuracy: 0.5075 - val_loss: 5.5785 - val_accuracy: 0.1436 - 981ms/epoch - 4ms/step
# Epoch 93/101
# 240/240 - 1s - loss: 1.2335 - accuracy: 0.5104 - val_loss: 2.4764 - val_accuracy: 0.2264 - 1s/epoch - 4ms/step
# Epoch 94/101
# 240/240 - 1s - loss: 1.2341 - accuracy: 0.5104 - val_loss: 8.0994 - val_accuracy: 0.1651 - 753ms/epoch - 3ms/step
# Epoch 95/101
# 240/240 - 1s - loss: 1.2262 - accuracy: 0.5150 - val_loss: 3.4354 - val_accuracy: 0.1177 - 865ms/epoch - 4ms/step
# Epoch 96/101
# 240/240 - 1s - loss: 1.2325 - accuracy: 0.5084 - val_loss: 5.1101 - val_accuracy: 0.0969 - 1s/epoch - 4ms/step
# Epoch 97/101
# 240/240 - 1s - loss: 1.2285 - accuracy: 0.5086 - val_loss: 2.6555 - val_accuracy: 0.2228 - 1s/epoch - 4ms/step
# Epoch 98/101
# 240/240 - 1s - loss: 1.2270 - accuracy: 0.5105 - val_loss: 8.0332 - val_accuracy: 0.1640 - 636ms/epoch - 3ms/step
# Epoch 99/101
# 240/240 - 1s - loss: 1.2300 - accuracy: 0.5093 - val_loss: 3.9233 - val_accuracy: 0.1931 - 897ms/epoch - 4ms/step
# Epoch 100/101
# 240/240 - 1s - loss: 1.2327 - accuracy: 0.5071 - val_loss: 6.7117 - val_accuracy: 0.1252 - 1s/epoch - 4ms/step
# Epoch 101/101
# epoch: 100, layer-1, i1: 1, i2: 0
# epoch: 100, layer-2, i1: 3, i2: 2
# epoch: 100, layer-3, i1: 5, i2: 4
# epoch: 100, layer-4, i1: 7, i2: 6
# epoch: 100, layer-5, i1: 9, i2: 8
# epoch: 100, layer-6, i1: 11, i2: 10
# epoch: 100, layer-7, i1: 13, i2: 12
# epoch: 100, layer-8, i1: 15, i2: 14
# epoch: 100, layer-9, i1: 17, i2: 16
# epoch: 100, layer-10, i1: 19, i2: 18
# epoch: 100, layer-11, i1: 21, i2: 20
# epoch: 100, layer-12, i1: 23, i2: 22
# epoch: 100, layer-13, i1: 25, i2: 24
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 - 6s - loss: 1.2261 - accuracy: 0.5106 - val_loss: 4.3749 - val_accuracy: 0.1412 - 6s/epoch - 24ms/step
# 1875/1875 - 2s - loss: 4.3755 - accuracy: 0.1391 - 2s/epoch - 913us/step
# 313/313 - 0s - loss: 4.3749 - accuracy: 0.1490 - 248ms/epoch - 791us/step

# %%
# %tensorboard --logdir ./logs/3301 --port 6013

# %% [markdown]
# # Step34 Overfit & Regularization

# %% [markdown]
# https://playground.tensorflow.org/
#
# https://deeperplayground.org/
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/1*_7OPgojau8hkiPUiHoGK_w.png" width="800"/>
#
# |   |   |
# |---|---|
#
# | <img src="https://developers.google.com/static/machine-learning/crash-course/images/HighLambda.svg" width="400"/> | <img src="https://developers.google.com/static/machine-learning/crash-course/images/LowLambda.svg" width="400"/> |
#
#
# When choosing a lambda value, the goal is to strike the right balance between simplicity and training-data fit:
#
# * If your lambda value is too high, your model will be simple, but you run the risk of underfitting your data. Your model won't learn enough about the training data to make useful predictions.
#
# * If your lambda value is too low, your model will be more complex, and you run the risk of overfitting your data. Your model will learn too much about the particularities of the training data, and won't be able to generalize to new data.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
#1
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# subsampling for overfitting
n_sample = 6000
x_train = x_train[:n_sample]
y_train = y_train[:n_sample]

#2:normalize images
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')
x_train /= 255.0 # [0, 1]
x_test  /= 255.0

#3: one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train) # (n_sample, 10)
y_test = tf.keras.utils.to_categorical(y_test)   # (10000,    10)

#4: build a model without regularization
act = "relu"
init = "he_uniform"
n = 100
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer = init))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer = init))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.summary()

#4-1: configure the model for training
opt = 'rmsprop' # tf.keras.optimizers.RMSprop(learning_rate=0.001) 
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])


logdir = './logs/' + "3401"

file_writer = tf.summary.create_file_writer(logdir + "/gradient")
file_writer.set_as_default()

#6:  calculate averages and histograms of gradients in layers
class GradientCallback(tf.keras.callbacks.Callback): 
  def __init__(self, freq=10):
##        super(GradientCallback, self).__init__()
      self.freq = freq

  def on_epoch_end(self, epoch, logs):
    if epoch%self.freq != 0:
        return

    with tf.GradientTape() as tape:
        y_pred = model(x_train)  # tensor, logits           
        loss   = tf.keras.losses.binary_crossentropy(y_train, y_pred)
    grads = tape.gradient(loss, model.trainable_weights)

    for n in range(1, len(model.layers)):
        i2 = (n-1)*2 # weights
        i1 = i2 + 1  # biases

        bias_avg   = tf.reduce_mean(tf.abs(grads[i1]))
        weight_avg = tf.reduce_mean(tf.abs(grads[i2]))
        
        tf.summary.scalar("layer_%d/avg/bias"%n, data=bias_avg, step=epoch)   
        tf.summary.scalar("layer_%d/avg/weight"%n, data=weight_avg, step=epoch)
        
        tf.summary.histogram("layer_%d/hist/bias"%n, data=grads[i1], step=epoch)
        tf.summary.histogram("layer_%d/hist/weight"%n, data=grads[i2], step=epoch)

        tf.print('epoch: {}, layer-{}, i1: {}, i2: {}'.format(epoch, n, i1, i2))
    
    feature_extractor = keras.Model(
        inputs=model.inputs,
        outputs=[layer.output for layer in model.layers],
    )
    features = feature_extractor(x_train)
    for i, f in enumerate(features):
      print('type_i: {}, type_f: {}'.format(type(i), type(f)))
      output_avg = tf.reduce_mean(tf.abs(f))
      tf.summary.scalar("layer_%d/avg/output"%i, data=output_avg, step=epoch)        
      tf.summary.histogram("layer_%d/hist/output"%i, data=f, step=epoch)
      
  def on_train_end(self, logs):
      tf.summary.flush()

callback1 = GradientCallback() # freq = 10
callback2 = tf.keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq= 10, profile_batch=0) 


#4-2: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=101, batch_size=400,
                                  validation_data = (x_test, y_test), verbose=0, callbacks=[callback1, callback2])
 
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2)
test_loss, test_acc   = model.evaluate(x_test,  y_test, verbose=2)

#4-3: plot accuracies
plt.title("Without regularization by %s traing data in mnist"%n_sample)
plt.plot(ret.history['accuracy'],     "b-", label="train accuracy")
plt.plot(ret.history['val_accuracy'], "r-", label="val accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(loc="best")
plt.show()

#5: build a model with weight regularization
reg = tf.keras.regularizers.l2(0.01)  # L2: 0.01, 0.1, 0.5
model2 = tf.keras.Sequential()
model2.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model2.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer = init,
                                 kernel_regularizer=reg))
model2.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer = init,
                                 kernel_regularizer=reg))
model2.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model2.summary()
 
#5-1: configure the model for training
model2.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
                                 
#5-2: train and evaluate the model
ret2 = model2.fit(x_train, y_train, epochs=201, batch_size=400,
                                    validation_data = (x_test, y_test), verbose=0, callbacks=[callback1, callback2])
train_loss2, train_acc2 = model2.evaluate(x_train, y_train, verbose=2)
test_loss2,  test_acc2  = model2.evaluate(x_test,  y_test,  verbose=2)

#5-3: plot accuracy
plt.title("With regularization by %s traing data in mnist"%n_sample)
plt.plot(ret2.history['accuracy'],     "b-", label="train accuracy")
plt.plot(ret2.history['val_accuracy'], "r-", label="val accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(loc="best")
plt.show()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_16 (Flatten)        (None, 784)               0
#
#  dense_108 (Dense)           (None, 100)               78500
#
#  dense_109 (Dense)           (None, 100)               10100
#
#  dense_110 (Dense)           (None, 10)                1010
#
# =================================================================
# Total params: 89,610
# Trainable params: 89,610
# Non-trainable params: 0
# _________________________________________________________________
# epoch: 0, layer-1, i1: 1, i2: 0
# epoch: 0, layer-2, i1: 3, i2: 2
# epoch: 0, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 10, layer-1, i1: 1, i2: 0
# epoch: 10, layer-2, i1: 3, i2: 2
# epoch: 10, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 20, layer-1, i1: 1, i2: 0
# epoch: 20, layer-2, i1: 3, i2: 2
# epoch: 20, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 30, layer-1, i1: 1, i2: 0
# epoch: 30, layer-2, i1: 3, i2: 2
# epoch: 30, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 40, layer-1, i1: 1, i2: 0
# epoch: 40, layer-2, i1: 3, i2: 2
# epoch: 40, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 50, layer-1, i1: 1, i2: 0
# epoch: 50, layer-2, i1: 3, i2: 2
# epoch: 50, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 60, layer-1, i1: 1, i2: 0
# epoch: 60, layer-2, i1: 3, i2: 2
# epoch: 60, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 70, layer-1, i1: 1, i2: 0
# epoch: 70, layer-2, i1: 3, i2: 2
# epoch: 70, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 80, layer-1, i1: 1, i2: 0
# epoch: 80, layer-2, i1: 3, i2: 2
# epoch: 80, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 90, layer-1, i1: 1, i2: 0
# epoch: 90, layer-2, i1: 3, i2: 2
# epoch: 90, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 100, layer-1, i1: 1, i2: 0
# epoch: 100, layer-2, i1: 3, i2: 2
# epoch: 100, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 188/188 - 0s - loss: 1.9706e-04 - accuracy: 1.0000 - 192ms/epoch - 1ms/step
# 313/313 - 0s - loss: 0.3039 - accuracy: 0.9462 - 203ms/epoch - 648us/step
# epoch: 0, layer-1, i1: 1, i2: 0
# epoch: 0, layer-2, i1: 3, i2: 2
# epoch: 0, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 10, layer-1, i1: 1, i2: 0
# epoch: 10, layer-2, i1: 3, i2: 2
# epoch: 10, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 20, layer-1, i1: 1, i2: 0
# epoch: 20, layer-2, i1: 3, i2: 2
# epoch: 20, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 30, layer-1, i1: 1, i2: 0
# epoch: 30, layer-2, i1: 3, i2: 2
# epoch: 30, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 40, layer-1, i1: 1, i2: 0
# epoch: 40, layer-2, i1: 3, i2: 2
# epoch: 40, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 50, layer-1, i1: 1, i2: 0
# epoch: 50, layer-2, i1: 3, i2: 2
# epoch: 50, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 60, layer-1, i1: 1, i2: 0
# epoch: 60, layer-2, i1: 3, i2: 2
# epoch: 60, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 70, layer-1, i1: 1, i2: 0
# epoch: 70, layer-2, i1: 3, i2: 2
# epoch: 70, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 80, layer-1, i1: 1, i2: 0
# epoch: 80, layer-2, i1: 3, i2: 2
# epoch: 80, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 90, layer-1, i1: 1, i2: 0
# epoch: 90, layer-2, i1: 3, i2: 2
# epoch: 90, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 100, layer-1, i1: 1, i2: 0
# epoch: 100, layer-2, i1: 3, i2: 2
# epoch: 100, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 110, layer-1, i1: 1, i2: 0
# epoch: 110, layer-2, i1: 3, i2: 2
# epoch: 110, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 120, layer-1, i1: 1, i2: 0
# epoch: 120, layer-2, i1: 3, i2: 2
# epoch: 120, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 130, layer-1, i1: 1, i2: 0
# epoch: 130, layer-2, i1: 3, i2: 2
# epoch: 130, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 140, layer-1, i1: 1, i2: 0
# epoch: 140, layer-2, i1: 3, i2: 2
# epoch: 140, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 150, layer-1, i1: 1, i2: 0
# epoch: 150, layer-2, i1: 3, i2: 2
# epoch: 150, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 160, layer-1, i1: 1, i2: 0
# epoch: 160, layer-2, i1: 3, i2: 2
# epoch: 160, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 170, layer-1, i1: 1, i2: 0
# epoch: 170, layer-2, i1: 3, i2: 2
# epoch: 170, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 180, layer-1, i1: 1, i2: 0
# epoch: 180, layer-2, i1: 3, i2: 2
# epoch: 180, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 190, layer-1, i1: 1, i2: 0
# epoch: 190, layer-2, i1: 3, i2: 2
# epoch: 190, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# epoch: 200, layer-1, i1: 1, i2: 0
# epoch: 200, layer-2, i1: 3, i2: 2
# epoch: 200, layer-3, i1: 5, i2: 4
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 188/188 - 0s - loss: 0.2249 - accuracy: 0.9867 - 191ms/epoch - 1ms/step
# 313/313 - 0s - loss: 0.3432 - accuracy: 0.9411 - 223ms/epoch - 714us/step

# %%
# %tensorboard --logdir ./logs/3401 --port 6014

# %% [markdown]
# #Step35 Dropout

# %% [markdown]
# <img src="https://laid.delanover.com/wp-content/uploads/2018/02/dropout.png" width="400"/>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
#1
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# subsampling for overfitting
n_sample = 6000
x_train = x_train[:n_sample]
y_train = y_train[:n_sample]

#2:normalize images
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')
x_train /= 255.0 # [0, 1]
x_test  /= 255.0

#3: one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train) # (n_sample, 10)
y_test = tf.keras.utils.to_categorical(y_test)   # (10000,    10)

#4: build a model with dropout
act = "relu"
init = "he_uniform"

n = 100
dropout_rate = 0.2  # 0.5
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer = init))
model.add(tf.keras.layers.Dropout( rate=dropout_rate))

model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer = init))
model.add(tf.keras.layers.Dropout( rate=dropout_rate))

model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.summary()

#4-1: configure the model for training
##opt = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])


logdir = './logs/' + "3501"

file_writer = tf.summary.create_file_writer(logdir + "/gradient")
file_writer.set_as_default()

#6:  calculate averages and histograms of gradients in layers
callback = tf.keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq= 10, profile_batch=0) 


#4-2: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=201, batch_size=400,
                                  validation_data = (x_test, y_test), verbose=0, callbacks=[callback])
 
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2)
test_loss, test_acc   = model.evaluate(x_test,  y_test, verbose=2)

#4-3: plot accuracies
plt.title("Dropout rate = %s, %s traing data in mnist"%(dropout_rate, n_sample))
plt.plot(ret.history['accuracy'],     "b-", label="train accuracy")
plt.plot(ret.history['val_accuracy'], "r-", label="val accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(loc="best")
plt.show()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_20 (Flatten)        (None, 784)               0
#
#  dense_120 (Dense)           (None, 100)               78500
#
#  dropout_4 (Dropout)         (None, 100)               0
#
#  dense_121 (Dense)           (None, 100)               10100
#
#  dropout_5 (Dropout)         (None, 100)               0
#
#  dense_122 (Dense)           (None, 10)                1010
#
# =================================================================
# Total params: 89,610
# Trainable params: 89,610
# Non-trainable params: 0
# _________________________________________________________________
# 188/188 - 0s - loss: 2.5033e-05 - accuracy: 1.0000 - 165ms/epoch - 877us/step
# 313/313 - 0s - loss: 0.3236 - accuracy: 0.9480 - 213ms/epoch - 680us/step

# %%
# %tensorboard --logdir ./logs/3501 --port 6015
# Out:
#       <iframe id="tensorboard-frame-90cab6f10301d561" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-90cab6f10301d561");
#           const url = new URL("/", window.location);
#           const port = 6015;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
